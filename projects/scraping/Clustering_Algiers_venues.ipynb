# %% [markdown]
# <h1>What is the best place to start a business in Algiers</h1>

# %%
import numpy as np
import pandas as pd
import urllib.request
import time
import requests
# !conda install -c conda-forge folium  --yes
import folium # map rendering library
from bs4 import BeautifulSoup
from urllib.request import urlopen
from geopy.geocoders import Nominatim
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
print("Imports done")
# Out:
# /bin/bash: conda: command not found
# Imports done

# %%
#Scraping Algiers_Province townships
url_city_1 = "https://en.wikipedia.org/wiki/Algiers_Province"
url_city_2 ="https://fr.wikipedia.org/wiki/Casablanca"
html_1=urlopen(url_city_1)
html_2=urlopen(url_city_2)
Soup_Algiers = BeautifulSoup(html_1,'html.parser')
Soup_Algiers= Soup_Algiers.find('div',attrs={'class' :'div-col'})

# %%
Soup_Algiers
# Out:
# <div class="div-col columns column-width" style="-moz-column-width: 18em; -webkit-column-width: 18em; column-width: 18em;">
# <ol><li><a href="/wiki/Alger_Centre" title="Alger Centre">Alger Centre</a></li>
# <li><a href="/wiki/A%C3%AFn_B%C3%A9nian,_Algiers" title="Aïn Bénian, Algiers">Aïn Bénian</a></li>
# <li><a href="/wiki/A%C3%AFn_Taya" title="Aïn Taya">Aïn Taya</a> (<a class="mw-redirect" href="/wiki/Ain-Taya" title="Ain-Taya">Ain-Taya</a>)</li>
# <li><a href="/wiki/Bab_El_Oued" title="Bab El Oued">Bab El Oued</a></li>
# <li><a href="/wiki/Bab_Ezzouar" title="Bab Ezzouar">Bab Ezzouar</a></li>
# <li><a href="/wiki/Baba_Hassen" title="Baba Hassen">Baba Hassen</a></li>
# <li><a href="/wiki/Bachdjerrah" title="Bachdjerrah">Bachdjerrah</a> (<a class="mw-redirect" href="/wiki/Bach_Djerrah" title="Bach Djerrah">Bach Djerrah</a>)</li>
# <li><a class="mw-redirect" href="/wiki/Baraki,_Algeria" title="Baraki, Algeria">Baraki</a></li>
# <li><a href="/wiki/Ben_Aknoun" title="Ben Aknoun">Ben Aknoun</a></li>
# <li><a href="/wiki/Bir_Mourad_Ra%C3%AFs" title="Bir Mourad Raïs">Bir Mourad Raïs</a></li>
# <li><a href="/wiki/Birkhadem" title="Birkhadem">Birkhadem</a> (<a class="mw-redirect" href="/wiki/Bir_Khadem" title="Bir Khadem">Bir Khadem</a>)</li>
# <li><a href="/wiki/Birtouta" title="Birtouta">Birtouta</a></li>
# <li><a href="/wiki/Bologhine" title="Bologhine">Bologhine</a> (<a class="mw-redirect" href="/wiki/Bouloghine" title="Bouloghine">Bouloghine</a>)</li>
# <li><a href="/wiki/Bordj_El_Bahri" title="Bordj El Bahri">Bordj El Bahri</a></li>
# <li><a href="/wiki/Bordj_El_Kiffan" title="Bordj El Kiffan">Bordj El Kiffan</a> (<a class="mw-redirect" href="/wiki/Bordj_El_Kifan" title="Bordj El Kifan">Bordj El Kifan</a>)</li>
# <li><a href="/wiki/Bourouba" title="Bourouba">Bourouba</a></li>
# <li><a href="/wiki/Bouzar%C3%A9ah" title="Bouzaréah">Bouzaréah</a></li>
# <li><a href="/wiki/B%C3%A9ni_Messous" title="Béni Messous">Béni Messous</a></li>
# <li><a class="mw-redirect" href="/wiki/Casbah" title="Casbah">Casbah</a></li>
# <li><a href="/wiki/Ch%C3%A9raga" title="Chéraga">Chéraga</a></li>
# <li><a href="/wiki/Dar_El_Be%C3%AFda" title="Dar El Beïda">Dar El Beïda</a></li>
# <li><a href="/wiki/Dou%C3%A9ra" title="Douéra">Douéra</a></li>
# <li><a href="/wiki/Draria" title="Draria">Draria</a></li>
# <li><a href="/wiki/D%C3%A9ly_Ibrahim" title="Dély Ibrahim">Dély Ibrahim</a> (<a class="mw-redirect" href="/wiki/Dely_Brahim" title="Dely Brahim">Dely Brahim</a>)</li>
# <li><a href="/wiki/El_Achour" title="El Achour">El Achour</a></li>
# <li><a href="/wiki/El_Biar" title="El Biar">El Biar</a></li>
# <li><a href="/wiki/El_Harrach" title="El Harrach">El Harrach</a></li>
# <li><a href="/wiki/El_Madania" title="El Madania">El Madania</a></li>
# <li><a href="/wiki/El_Magharia" title="El Magharia">El Magharia</a></li>
# <li><a href="/wiki/El_Marsa,_Algiers" title="El Marsa, Algiers">El Marsa</a></li>
# <li><a href="/wiki/El_Mouradia" title="El Mouradia">El Mouradia</a></li>
# <li><a href="/wiki/Djasr_Kasentina" title="Djasr Kasentina">Djasr Kasentina</a></li>
# <li><a href="/wiki/H%27raoua" title="H'raoua">H'raoua</a></li>
# <li><a href="/wiki/Hammamet,_Algiers" title="Hammamet, Algiers">Hammamet</a></li>
# <li><a href="/wiki/Hussein_Dey_(commune)" title="Hussein Dey (commune)">Hussein Dey</a></li>
# <li><a href="/wiki/Hydra,_Algeria" title="Hydra, Algeria">Hydra</a></li>
# <li><a href="/wiki/Khra%C3%AFcia" title="Khraïcia">Khraïcia</a></li>
# <li><a href="/wiki/Kouba,_Algeria" title="Kouba, Algeria">Kouba</a></li>
# <li><a href="/wiki/Les_Eucalyptus" title="Les Eucalyptus">Les Eucalyptus</a></li>
# <li><a href="/wiki/Mahelma" title="Mahelma">Mahelma</a></li>
# <li><a href="/wiki/Mohamed_Belouizdad" title="Mohamed Belouizdad">Mohamed Belouizdad</a></li>
# <li><a class="mw-redirect" href="/wiki/Mohammedia_(Algiers_Province)" title="Mohammedia (Algiers Province)">Mohammedia</a></li>
# <li><a href="/wiki/Oued_Koriche" title="Oued Koriche">Oued Koriche</a></li>
# <li><a href="/wiki/Oued_Smar" title="Oued Smar">Oued Smar</a></li>
# <li><a href="/wiki/Ouled_Chebel" title="Ouled Chebel">Ouled Chebel</a></li>
# <li><a href="/wiki/Ouled_Fayet" title="Ouled Fayet">Ouled Fayet</a></li>
# <li><a href="/wiki/Rahmania" title="Rahmania">Rahmania</a></li>
# <li><a href="/wiki/Ra%C3%AFs_Hamidou" title="Raïs Hamidou">Raïs Hamidou</a></li>
# <li><a href="/wiki/Regha%C3%AFa" title="Reghaïa">Reghaïa</a></li>
# <li><a href="/wiki/Rou%C3%AFba" title="Rouïba">Rouïba</a></li>
# <li><a href="/wiki/Saoula" title="Saoula">Saoula</a></li>
# <li><a href="/wiki/Sidi_M%27Hamed" title="Sidi M'Hamed">Sidi M'Hamed</a> (<a class="mw-redirect" href="/wiki/Sidi_Mhamed" title="Sidi Mhamed">Sidi Mhamed</a>)</li>
# <li><a href="/wiki/Sidi_Moussa,_Algeria" title="Sidi Moussa, Algeria">Sidi Moussa</a></li>
# <li><a href="/wiki/Souidania" title="Souidania">Souidania</a></li>
# <li><a href="/wiki/Staou%C3%A9li" title="Staouéli">Staouéli</a></li>
# <li><a href="/wiki/Tessala_El_Merdja" title="Tessala El Merdja">Tessala El Merdja</a></li>
# <li><a href="/wiki/Z%C3%A9ralda" title="Zéralda">Zéralda</a></li></ol>
# </div>

# %%
#creating a list of all townships in Algiers City
def Townships_list(soup):
  lis=soup.find_all('li')
  data=[]
  for li in lis[0:]:
      result = li.text.strip().replace(u'\xa0', u'').replace(';','')
      data.append(result)
  return data

# %%
Algiers_Townships=Townships_list(Soup_Algiers)

# %%
#Manually adding lacking data
Algiers_Townships[6]= 'Bachdjerrah'
Algiers_Townships[10]='Birkhadem'
Algiers_Townships[12]='Bologhine'

# %%
Algiers_Townships
# Out:
# ['Alger Centre',
#  'Aïn Bénian',
#  'Aïn Taya (Ain-Taya)',
#  'Bab El Oued',
#  'Bab Ezzouar',
#  'Baba Hassen',
#  'Bachdjerrah',
#  'Baraki',
#  'Ben Aknoun',
#  'Bir Mourad Raïs',
#  'Birkhadem',
#  'Birtouta',
#  'Bologhine',
#  'Bordj El Bahri',
#  'Bordj El Kiffan (Bordj El Kifan)',
#  'Bourouba',
#  'Bouzaréah',
#  'Béni Messous',
#  'Casbah',
#  'Chéraga',
#  'Dar El Beïda',
#  'Douéra',
#  'Draria',
#  'Dély Ibrahim (Dely Brahim)',
#  'El Achour',
#  'El Biar',
#  'El Harrach',
#  'El Madania',
#  'El Magharia',
#  'El Marsa',
#  'El Mouradia',
#  'Djasr Kasentina',
#  "H'raoua",
#  'Hammamet',
#  'Hussein Dey',
#  'Hydra',
#  'Khraïcia',
#  'Kouba',
#  'Les Eucalyptus',
#  'Mahelma',
#  'Mohamed Belouizdad',
#  'Mohammedia',
#  'Oued Koriche',
#  'Oued Smar',
#  'Ouled Chebel',
#  'Ouled Fayet',
#  'Rahmania',
#  'Raïs Hamidou',
#  'Reghaïa',
#  'Rouïba',
#  'Saoula',
#  "Sidi M'Hamed (Sidi Mhamed)",
#  'Sidi Moussa',
#  'Souidania',
#  'Staouéli',
#  'Tessala El Merdja',
#  'Zéralda']

# %%
#creating dataframe of algiers townships
Algiers=pd.DataFrame(Algiers_Townships,columns=['Township'])

# %%
Algiers
# Out:
#                             Township
# 0                       Alger Centre
# 1                         Aïn Bénian
# 2                Aïn Taya (Ain-Taya)
# 3                        Bab El Oued
# 4                        Bab Ezzouar
# 5                        Baba Hassen
# 6                        Bachdjerrah
# 7                             Baraki
# 8                         Ben Aknoun
# 9                    Bir Mourad Raïs
# 10                         Birkhadem
# 11                          Birtouta
# 12                         Bologhine
# 13                    Bordj El Bahri
# 14  Bordj El Kiffan (Bordj El Kifan)
# 15                          Bourouba
# 16                         Bouzaréah
# 17                      Béni Messous
# 18                            Casbah
# 19                           Chéraga
# 20                      Dar El Beïda
# 21                            Douéra
# 22                            Draria
# 23        Dély Ibrahim (Dely Brahim)
# 24                         El Achour
# 25                           El Biar
# 26                        El Harrach
# 27                        El Madania
# 28                       El Magharia
# 29                          El Marsa
# 30                       El Mouradia
# 31                   Djasr Kasentina
# 32                           H'raoua
# 33                          Hammamet
# 34                       Hussein Dey
# 35                             Hydra
# 36                          Khraïcia
# 37                             Kouba
# 38                    Les Eucalyptus
# 39                           Mahelma
# 40                Mohamed Belouizdad
# 41                        Mohammedia
# 42                      Oued Koriche
# 43                         Oued Smar
# 44                      Ouled Chebel
# 45                       Ouled Fayet
# 46                          Rahmania
# 47                      Raïs Hamidou
# 48                           Reghaïa
# 49                            Rouïba
# 50                            Saoula
# 51        Sidi M'Hamed (Sidi Mhamed)
# 52                       Sidi Moussa
# 53                         Souidania
# 54                          Staouéli
# 55                 Tessala El Merdja
# 56                           Zéralda

# %%
#Getting the Latitude and longitude of the townships one by one
def coordinates_city(city_list,City):
   lat=[]
   lon=[]
   for town in city_list:
        geolocator = Nominatim(user_agent="Explorer")
        location = geolocator.geocode(town+','+City)
        if location:
          latitude = location.latitude
          longitude = location.longitude
        else:
          latitude='None'
          longitude='None'
        lat.append(latitude)
        lon.append(longitude)
   City_coordinates=pd.DataFrame({'Latitude':lat,'Longitude':lon})
   return City_coordinates

# %%
Algiers_city=coordinates_city(Algiers_Townships,'Algiers')
Algiers_city['Township']=Algiers['Township']
Algiers_city
# Out:
#      Latitude  Longitude                          Township
# 0   36.776302   3.058486                      Alger Centre
# 1   36.803804   2.921601                        Aïn Bénian
# 2   36.792881   3.292923               Aïn Taya (Ain-Taya)
# 3   36.790665   3.049736                       Bab El Oued
# 4   36.721997   3.185660                       Bab Ezzouar
# 5   36.694378   2.971822                       Baba Hassen
# 6   36.723026   3.113073                       Bachdjerrah
# 7   36.642065   3.108432                            Baraki
# 8   36.759271   3.019717                        Ben Aknoun
# 9   36.707037   3.040779                   Bir Mourad Raïs
# 10  36.715460   3.049071                         Birkhadem
# 11  36.623933   2.972846                          Birtouta
# 12  36.804678   3.042617                         Bologhine
# 13  36.790795   3.250177                    Bordj El Bahri
# 14  36.747273   3.190895  Bordj El Kiffan (Bordj El Kifan)
# 15  36.717403   3.121664                          Bourouba
# 16  36.777520   2.997065                         Bouzaréah
# 17  36.779616   2.975394                      Béni Messous
# 18  36.784677   3.059586                            Casbah
# 19  36.758945   2.945459                           Chéraga
# 20  36.741000   3.187659                      Dar El Beïda
# 21  36.669409   2.942103                            Douéra
# 22  36.689570   2.973539                            Draria
# 23  36.751970   2.981650        Dély Ibrahim (Dely Brahim)
# 24  36.734162   2.990524                         El Achour
# 25  36.768998   3.029947                           El Biar
# 26  36.721231   3.137410                        El Harrach
# 27  36.742007   3.066571                        El Madania
# 28  36.731335   3.108557                       El Magharia
# 29  36.809128   3.254604                          El Marsa
# 30  36.747496   3.050094                       El Mouradia
# 31  36.692940   3.071310                   Djasr Kasentina
# 32  36.772746   3.308501                           H'raoua
# 33  36.812813   2.973815                          Hammamet
# 34  36.730413   3.087835                       Hussein Dey
# 35  36.747426   3.040183                             Hydra
# 36  36.677187   2.981770                          Khraïcia
# 37  36.733768   3.086179                             Kouba
# 38  36.656714   3.147262                    Les Eucalyptus
# 39  36.682363   2.877650                           Mahelma
# 40  36.744241   3.078396                Mohamed Belouizdad
# 41  36.728871   3.146918                        Mohammedia
# 42  36.784924   3.043447                      Oued Koriche
# 43  36.704420   3.168156                         Oued Smar
# 44  36.608387   2.990543                      Ouled Chebel
# 45  36.735525   2.950906                       Ouled Fayet
# 46  36.680763   2.906431                          Rahmania
# 47  36.817336   3.011517                      Raïs Hamidou
# 48  36.738781   3.342118                           Reghaïa
# 49  36.742651   3.310621                            Rouïba
# 50  36.702446   3.026597                            Saoula
# 51  36.764424   3.049632        Sidi M'Hamed (Sidi Mhamed)
# 52  36.606254   3.088146                       Sidi Moussa
# 53  36.707975   2.912559                         Souidania
# 54  36.753340   2.888176                          Staouéli
# 55  36.630719   2.945517                 Tessala El Merdja
# 56  36.699282   2.867284                           Zéralda

# %%
# create map of Algiers using latitude and longitude values marked in its townships
def folium_marked_map(City_df,City_name):
  geolocator = Nominatim(user_agent="Explorer")
  location = geolocator.geocode(City_name)
  map_city = folium.Map(location=[location.latitude,location.longitude], zoom_start=10)
  # add markers to map
  for lt, lng, town in zip(City_df['Latitude'], City_df['Longitude'], City_df['Township']):
    label = town
    label = folium.Popup(label,parse_html=True)
    folium.CircleMarker(
      [lt, lng],
      radius=5,
      popup=label,
      color='blue',
      fill=True,
      fill_color='#3186cc',
      fill_opacity=0.7,
      parse_html=False).add_to(map_city)
  return map_city

# %%
folium_marked_map(Algiers_city,'Algiers')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#foursquare api credentials 
CLIENT_ID ="UVG2CCUNHMIMZJWSWZQK2U0Y2NOIDMQWP3KGPMY0DPRA0BTM"
CLIENT_SECRET= "FJJJZP4CPMEUGFASWM5JKOETBZOMS3ERBJ03UF3U0NDH1V3U"
VERSION="20200605"

# %%
#functions to get nearby venues for a location using foursquare api
def getNearbyVenues(names, latitudes, longitudes, radius=3000):
    LIMIT=2000
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT
            )
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Township', 
                  'Township Latitude', 
                  'Township Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
#creating a datframe of algiers venues
Algiers_venues = getNearbyVenues(names=Algiers_city['Township'],
                                   latitudes=Algiers_city['Latitude'],
                                   longitudes=Algiers_city['Longitude']
                                  )
# Out:
# Alger Centre
# Aïn Bénian
# Aïn Taya (Ain-Taya)
# Bab El Oued
# Bab Ezzouar
# Baba Hassen
# Bachdjerrah
# Baraki
# Ben Aknoun
# Bir Mourad Raïs
# Birkhadem
# Birtouta
# Bologhine
# Bordj El Bahri
# Bordj El Kiffan (Bordj El Kifan)
# Bourouba
# Bouzaréah
# Béni Messous
# Casbah
# Chéraga
# Dar El Beïda
# Douéra
# Draria
# Dély Ibrahim (Dely Brahim)
# El Achour
# El Biar
# El Harrach
# El Madania
# El Magharia
# El Marsa
# El Mouradia
# Djasr Kasentina
# H'raoua
# Hammamet
# Hussein Dey
# Hydra
# Khraïcia
# Kouba
# Les Eucalyptus
# Mahelma
# Mohamed Belouizdad
# Mohammedia
# Oued Koriche
# Oued Smar
# Ouled Chebel
# Ouled Fayet
# Rahmania
# Raïs Hamidou
# Reghaïa
# Rouïba
# Saoula
# Sidi M'Hamed (Sidi Mhamed)
# Sidi Moussa
# Souidania
# Staouéli
# Tessala El Merdja
# Zéralda

# %%
Algiers_venues
# Out:
#               Township  Township Latitude  ...  Venue Longitude     Venue Category
# 0         Alger Centre          36.776302  ...         3.058731          BBQ Joint
# 1         Alger Centre          36.776302  ...         3.060508            Theater
# 2         Alger Centre          36.776302  ...         3.053610  French Restaurant
# 3         Alger Centre          36.776302  ...         3.060310               Café
# 4         Alger Centre          36.776302  ...         3.058273         Art Museum
# ..                 ...                ...  ...              ...                ...
# 872  Tessala El Merdja          36.630719  ...         2.968677      Garden Center
# 873            Zéralda          36.699282  ...         2.887300         Campground
# 874            Zéralda          36.699282  ...         2.841833          BBQ Joint
# 875            Zéralda          36.699282  ...         2.849113              Hotel
# 876            Zéralda          36.699282  ...         2.843933              Hotel
#
# [877 rows x 7 columns]

# %%
print('There are {} uniques categories in algiers venues.'.format(len(Algiers_venues['Venue Category'].unique())))
# Out:
# There are 87 uniques categories in algiers venues.

# %%
#Algiers venueq[['Venue category]] is the dataframe column containing all categories of venues in Algiers
Algiers_dummies = pd.get_dummies(Algiers_venues[['Venue Category']], prefix="", prefix_sep="")
Algiers_dummies['Township']=Algiers_venues['Township']
Algiers_dummies
# Out:
#      African Restaurant  Airport  ...  Video Game Store           Township
# 0                     0        0  ...                 0       Alger Centre
# 1                     0        0  ...                 0       Alger Centre
# 2                     0        0  ...                 0       Alger Centre
# 3                     0        0  ...                 0       Alger Centre
# 4                     0        0  ...                 0       Alger Centre
# ..                  ...      ...  ...               ...                ...
# 872                   0        0  ...                 0  Tessala El Merdja
# 873                   0        0  ...                 0            Zéralda
# 874                   0        0  ...                 0            Zéralda
# 875                   0        0  ...                 0            Zéralda
# 876                   0        0  ...                 0            Zéralda
#
# [877 rows x 88 columns]

# %%
# move neighborhood column to the first column
fixed_columns = [Algiers_dummies.columns[-1]] + list(Algiers_dummies.columns[:-1])
Algiers_dummies = Algiers_dummies[fixed_columns]
Algiers_dummies
# Out:
#               Township  ...  Video Game Store
# 0         Alger Centre  ...                 0
# 1         Alger Centre  ...                 0
# 2         Alger Centre  ...                 0
# 3         Alger Centre  ...                 0
# 4         Alger Centre  ...                 0
# ..                 ...  ...               ...
# 872  Tessala El Merdja  ...                 0
# 873            Zéralda  ...                 0
# 874            Zéralda  ...                 0
# 875            Zéralda  ...                 0
# 876            Zéralda  ...                 0
#
# [877 rows x 88 columns]

# %%
Algiers_grouped = Algiers_dummies.groupby('Township').mean().reset_index()

# %%
Algiers_grouped.shape
# Out:
# (55, 88)

# %%
Algiers_grouped
# Out:
#                             Township  ...  Video Game Store
# 0                       Alger Centre  ...          0.026316
# 1                         Aïn Bénian  ...          0.000000
# 2                Aïn Taya (Ain-Taya)  ...          0.000000
# 3                        Bab El Oued  ...          0.034483
# 4                        Bab Ezzouar  ...          0.000000
# 5                        Baba Hassen  ...          0.000000
# 6                        Bachdjerrah  ...          0.000000
# 7                             Baraki  ...          0.000000
# 8                         Ben Aknoun  ...          0.000000
# 9                    Bir Mourad Raïs  ...          0.000000
# 10                         Birkhadem  ...          0.000000
# 11                          Birtouta  ...          0.000000
# 12                         Bologhine  ...          0.000000
# 13                    Bordj El Bahri  ...          0.000000
# 14  Bordj El Kiffan (Bordj El Kifan)  ...          0.000000
# 15                          Bourouba  ...          0.000000
# 16                         Bouzaréah  ...          0.000000
# 17                      Béni Messous  ...          0.000000
# 18                            Casbah  ...          0.028571
# 19                           Chéraga  ...          0.000000
# 20                      Dar El Beïda  ...          0.000000
# 21                   Djasr Kasentina  ...          0.000000
# 22                            Douéra  ...          0.000000
# 23                            Draria  ...          0.000000
# 24        Dély Ibrahim (Dely Brahim)  ...          0.000000
# 25                         El Achour  ...          0.000000
# 26                           El Biar  ...          0.000000
# 27                        El Harrach  ...          0.000000
# 28                        El Madania  ...          0.000000
# 29                       El Magharia  ...          0.000000
# 30                          El Marsa  ...          0.000000
# 31                       El Mouradia  ...          0.000000
# 32                           H'raoua  ...          0.000000
# 33                          Hammamet  ...          0.000000
# 34                       Hussein Dey  ...          0.000000
# 35                             Hydra  ...          0.000000
# 36                          Khraïcia  ...          0.000000
# 37                             Kouba  ...          0.000000
# 38                           Mahelma  ...          0.000000
# 39                Mohamed Belouizdad  ...          0.000000
# 40                        Mohammedia  ...          0.000000
# 41                      Oued Koriche  ...          0.000000
# 42                         Oued Smar  ...          0.000000
# 43                      Ouled Chebel  ...          0.000000
# 44                       Ouled Fayet  ...          0.000000
# 45                          Rahmania  ...          0.000000
# 46                      Raïs Hamidou  ...          0.000000
# 47                           Reghaïa  ...          0.000000
# 48                            Rouïba  ...          0.000000
# 49                            Saoula  ...          0.000000
# 50        Sidi M'Hamed (Sidi Mhamed)  ...          0.000000
# 51                         Souidania  ...          0.000000
# 52                          Staouéli  ...          0.000000
# 53                 Tessala El Merdja  ...          0.000000
# 54                           Zéralda  ...          0.000000
#
# [55 rows x 88 columns]

# %%
#Get insight of the most common venues in every Township
num_top_venues = 5
for hood in Algiers_grouped['Township']:
    print("----"+hood+"----")
    temp = Algiers_grouped[Algiers_grouped['Township'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Alger Centre----
#                venue  freq
# 0              Hotel  0.16
# 1               Café  0.11
# 2    Harbor / Marina  0.08
# 3         Art Museum  0.05
# 4  French Restaurant  0.05
#
#
# ----Aïn Bénian----
#                       venue  freq
# 0        Seafood Restaurant  0.50
# 1                     Beach  0.17
# 2  Mediterranean Restaurant  0.17
# 3         Fish & Chips Shop  0.17
# 4        African Restaurant  0.00
#
#
# ----Aïn Taya (Ain-Taya)----
#            venue  freq
# 0          Hotel   0.4
# 1          Beach   0.4
# 2      Dive Spot   0.2
# 3  Metro Station   0.0
# 4    Pizza Place   0.0
#
#
# ----Bab El Oued----
#                venue  freq
# 0              Hotel  0.17
# 1               Café  0.14
# 2         Art Museum  0.07
# 3  French Restaurant  0.07
# 4              Plaza  0.07
#
#
# ----Bab Ezzouar----
#                 venue  freq
# 0               Hotel  0.33
# 1          Restaurant  0.11
# 2  African Restaurant  0.06
# 3          Steakhouse  0.06
# 4   Recreation Center  0.06
#
#
# ----Baba Hassen----
#                         venue  freq
# 0   Middle Eastern Restaurant   0.2
# 1  Construction & Landscaping   0.2
# 2                 Pizza Place   0.2
# 3                  Restaurant   0.2
# 4                 Gaming Cafe   0.2
#
#
# ----Bachdjerrah----
#                     venue  freq
# 0                   Hotel  0.29
# 1  Furniture / Home Store  0.14
# 2                    Park  0.14
# 3                  Resort  0.14
# 4            Cupcake Shop  0.14
#
#
# ----Baraki----
#                 venue  freq
# 0         IT Services   1.0
# 1  African Restaurant   0.0
# 2       Metro Station   0.0
# 3         Pizza Place   0.0
# 4                Park   0.0
#
#
# ----Ben Aknoun----
#                venue  freq
# 0         Restaurant  0.14
# 1               Café  0.10
# 2              Diner  0.10
# 3  French Restaurant  0.07
# 4       Burger Joint  0.07
#
#
# ----Bir Mourad Raïs----
#                venue  freq
# 0  Convenience Store  0.25
# 1              Diner  0.25
# 2     Shop & Service  0.25
# 3               Café  0.25
# 4              Motel  0.00
#
#
# ----Birkhadem----
#               venue  freq
# 0              Café  0.19
# 1      Burger Joint  0.12
# 2        Restaurant  0.12
# 3             Diner  0.12
# 4  Department Store  0.06
#
#
# ----Birtouta----
#                 venue  freq
# 0       Garden Center   1.0
# 1  African Restaurant   0.0
# 2       Metro Station   0.0
# 3         Pizza Place   0.0
# 4                Park   0.0
#
#
# ----Bologhine----
#                 venue  freq
# 0          Art Museum  0.25
# 1                Park  0.25
# 2  Seafood Restaurant  0.25
# 3              Church  0.25
# 4  African Restaurant  0.00
#
#
# ----Bordj El Bahri----
#                       venue  freq
# 0  Mediterranean Restaurant  0.14
# 1            Ice Cream Shop  0.14
# 2           Harbor / Marina  0.14
# 3                     Beach  0.14
# 4                    Market  0.14
#
#
# ----Bordj El Kiffan (Bordj El Kifan)----
#                 venue  freq
# 0               Hotel   0.6
# 1  African Restaurant   0.1
# 2   Recreation Center   0.1
# 3          Restaurant   0.1
# 4       Shopping Mall   0.1
#
#
# ----Bourouba----
#                           venue  freq
# 0                       Stadium  0.17
# 1  Theme Park Ride / Attraction  0.17
# 2                        Market  0.17
# 3                Tennis Stadium  0.17
# 4                          Park  0.17
#
#
# ----Bouzaréah----
#                       venue  freq
# 0                Restaurant  0.23
# 1                     Hotel  0.15
# 2              Burger Joint  0.15
# 3         Indian Restaurant  0.08
# 4  Mediterranean Restaurant  0.08
#
#
# ----Béni Messous----
#                      venue  freq
# 0                    Diner  0.14
# 1                    Hotel  0.10
# 2               Restaurant  0.10
# 3  Comfort Food Restaurant  0.10
# 4       Italian Restaurant  0.05
#
#
# ----Casbah----
#                venue  freq
# 0              Hotel  0.14
# 1               Café  0.11
# 2         Art Museum  0.06
# 3  French Restaurant  0.06
# 4         Restaurant  0.06
#
#
# ----Chéraga----
#            venue  freq
# 0     Restaurant  0.15
# 1    Bus Station  0.08
# 2  Big Box Store  0.08
# 3         Office  0.08
# 4    Flower Shop  0.08
#
#
# ----Dar El Beïda----
#                       venue  freq
# 0                     Hotel  0.38
# 1                Restaurant  0.15
# 2              Burger Joint  0.08
# 3  Mediterranean Restaurant  0.08
# 4         French Restaurant  0.08
#
#
# ----Djasr Kasentina----
#                     venue  freq
# 0       Convenience Store  0.25
# 1           Train Station  0.25
# 2  Furniture / Home Store  0.25
# 3                   Hotel  0.25
# 4                    Tree  0.00
#
#
# ----Douéra----
#                        venue  freq
# 0                Gaming Cafe   0.5
# 1               Camera Store   0.5
# 2         African Restaurant   0.0
# 3  Middle Eastern Restaurant   0.0
# 4                Pizza Place   0.0
#
#
# ----Draria----
#                         venue  freq
# 0   Middle Eastern Restaurant  0.25
# 1  Construction & Landscaping  0.25
# 2                  Restaurant  0.25
# 3                 Gaming Cafe  0.25
# 4          African Restaurant  0.00
#
#
# ----Dély Ibrahim (Dely Brahim)----
#                 venue  freq
# 0               Diner  0.11
# 1  Turkish Restaurant  0.07
# 2         Pizza Place  0.07
# 3               Hotel  0.07
# 4   Indian Restaurant  0.07
#
#
# ----El Achour----
#                      venue  freq
# 0              Pizza Place  0.21
# 1                    Diner  0.11
# 2             Burger Joint  0.11
# 3  Comfort Food Restaurant  0.11
# 4       Falafel Restaurant  0.05
#
#
# ----El Biar----
#                       venue  freq
# 0                Restaurant  0.14
# 1                     Hotel  0.12
# 2                      Café  0.12
# 3  Mediterranean Restaurant  0.05
# 4         French Restaurant  0.05
#
#
# ----El Harrach----
#                       venue  freq
# 0                     Hotel   0.1
# 1  Mediterranean Restaurant   0.1
# 2                Restaurant   0.1
# 3               Salad Place   0.1
# 4             Shopping Mall   0.1
#
#
# ----El Madania----
#                venue  freq
# 0              Hotel  0.11
# 1         Restaurant  0.08
# 2       Burger Joint  0.06
# 3  French Restaurant  0.06
# 4        Pizza Place  0.06
#
#
# ----El Magharia----
#                       venue  freq
# 0                     Hotel  0.18
# 1  Mediterranean Restaurant  0.09
# 2                      Park  0.09
# 3                    Resort  0.09
# 4                Restaurant  0.09
#
#
# ----El Marsa----
#                       venue  freq
# 0  Mediterranean Restaurant  0.17
# 1            Ice Cream Shop  0.17
# 2           Harbor / Marina  0.17
# 3                     Beach  0.17
# 4        Seafood Restaurant  0.17
#
#
# ----El Mouradia----
#                venue  freq
# 0         Restaurant  0.12
# 1               Café  0.09
# 2  French Restaurant  0.07
# 3              Hotel  0.07
# 4              Diner  0.06
#
#
# ----H'raoua----
#            venue  freq
# 0          Hotel   0.4
# 1          Beach   0.4
# 2      Dive Spot   0.2
# 3  Metro Station   0.0
# 4    Pizza Place   0.0
#
#
# ----Hammamet----
#                 venue  freq
# 0  Turkish Restaurant  0.33
# 1               Motel  0.33
# 2                Café  0.33
# 3  African Restaurant  0.00
# 4       Metro Station  0.00
#
#
# ----Hussein Dey----
#                 venue  freq
# 0               Hotel  0.17
# 1          Restaurant  0.13
# 2  African Restaurant  0.04
# 3  Light Rail Station  0.04
# 4           Hotel Bar  0.04
#
#
# ----Hydra----
#                venue  freq
# 0               Café  0.12
# 1         Restaurant  0.11
# 2  French Restaurant  0.07
# 3              Diner  0.07
# 4       Burger Joint  0.05
#
#
# ----Khraïcia----
#                         venue  freq
# 0   Middle Eastern Restaurant  0.25
# 1  Construction & Landscaping  0.25
# 2                  Restaurant  0.25
# 3                 Gaming Cafe  0.25
# 4          African Restaurant  0.00
#
#
# ----Kouba----
#                 venue  freq
# 0               Hotel  0.20
# 1          Restaurant  0.12
# 2  African Restaurant  0.04
# 3           Hotel Bar  0.04
# 4              Lounge  0.04
#
#
# ----Mahelma----
#                         venue  freq
# 0                       Hotel  0.25
# 1                     Airport  0.25
# 2  Construction & Landscaping  0.25
# 3                  Campground  0.25
# 4   Middle Eastern Restaurant  0.00
#
#
# ----Mohamed Belouizdad----
#                 venue  freq
# 0               Hotel  0.16
# 1                Café  0.10
# 2          Restaurant  0.06
# 3  African Restaurant  0.03
# 4         Pizza Place  0.03
#
#
# ----Mohammedia----
#                       venue  freq
# 0                     Hotel  0.15
# 1             Shopping Mall  0.15
# 2  Mediterranean Restaurant  0.08
# 3         Recreation Center  0.08
# 4                Restaurant  0.08
#
#
# ----Oued Koriche----
#         venue  freq
# 0       Hotel  0.12
# 1  Restaurant  0.09
# 2        Café  0.09
# 3       Plaza  0.06
# 4  Art Museum  0.06
#
#
# ----Oued Smar----
#                        venue  freq
# 0                      Hotel  0.20
# 1                 Restaurant  0.10
# 2  Middle Eastern Restaurant  0.10
# 3              Shopping Mall  0.10
# 4                Coffee Shop  0.05
#
#
# ----Ouled Chebel----
#                 venue  freq
# 0          Toll Booth   1.0
# 1  African Restaurant   0.0
# 2       Metro Station   0.0
# 3         Pizza Place   0.0
# 4                Park   0.0
#
#
# ----Ouled Fayet----
#                         venue  freq
# 0                        Café  0.09
# 1               Big Box Store  0.09
# 2            Recording Studio  0.09
# 3                 Pizza Place  0.09
# 4  Construction & Landscaping  0.09
#
#
# ----Rahmania----
#          venue  freq
# 0      Airport   0.5
# 1   Campground   0.5
# 2         Pool   0.0
# 3  Pizza Place   0.0
# 4         Park   0.0
#
#
# ----Raïs Hamidou----
#                       venue  freq
# 0  Mediterranean Restaurant  0.50
# 1         Indian Restaurant  0.25
# 2                     Beach  0.25
# 3             Metro Station  0.00
# 4               Pizza Place  0.00
#
#
# ----Reghaïa----
#                 venue  freq
# 0               Diner   0.5
# 1      Clothing Store   0.5
# 2  African Restaurant   0.0
# 3                Pool   0.0
# 4         Pizza Place   0.0
#
#
# ----Rouïba----
#                   venue  freq
# 0                 Hotel  0.25
# 1                 Plaza  0.25
# 2                 Diner  0.25
# 3  Fast Food Restaurant  0.25
# 4                  Park  0.00
#
#
# ----Saoula----
#                 venue  freq
# 0                Café  0.25
# 1      Ice Cream Shop  0.25
# 2         Pizza Place  0.25
# 3                 Bar  0.25
# 4  African Restaurant  0.00
#
#
# ----Sidi M'Hamed (Sidi Mhamed)----
#              venue  freq
# 0            Hotel  0.11
# 1             Café  0.10
# 2       Restaurant  0.09
# 3  Harbor / Marina  0.04
# 4            Diner  0.04
#
#
# ----Souidania----
#          venue  freq
# 0      Airport   0.5
# 1   Campground   0.5
# 2         Pool   0.0
# 3  Pizza Place   0.0
# 4         Park   0.0
#
#
# ----Staouéli----
#                        venue  freq
# 0           Asian Restaurant  0.15
# 1                      Hotel  0.08
# 2  Middle Eastern Restaurant  0.08
# 3                       Pool  0.08
# 4                       Park  0.08
#
#
# ----Tessala El Merdja----
#                 venue  freq
# 0       Garden Center   1.0
# 1  African Restaurant   0.0
# 2       Metro Station   0.0
# 3         Pizza Place   0.0
# 4                Park   0.0
#
#
# ----Zéralda----
#            venue  freq
# 0          Hotel  0.50
# 1      BBQ Joint  0.25
# 2     Campground  0.25
# 3  Metro Station  0.00
# 4    Pizza Place  0.00

# %%
"return most common venues in a township"
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Township']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
Townships_venues_sorted = pd.DataFrame(columns=columns)
Townships_venues_sorted['Township'] = Algiers_grouped['Township']

for ind in np.arange(Algiers_grouped.shape[0]):
    Townships_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Algiers_grouped.iloc[ind, :], num_top_venues)

Townships_venues_sorted
# Out:
#                             Township  ...    10th Most Common Venue
# 0                       Alger Centre  ...                      Park
# 1                         Aïn Bénian  ...                     Diner
# 2                Aïn Taya (Ain-Taya)  ...        Falafel Restaurant
# 3                        Bab El Oued  ...        Italian Restaurant
# 4                        Bab Ezzouar  ...        Italian Restaurant
# 5                        Baba Hassen  ...          Department Store
# 6                        Bachdjerrah  ...                    Cruise
# 7                             Baraki  ...        Falafel Restaurant
# 8                         Ben Aknoun  ...               Coffee Shop
# 9                    Bir Mourad Raïs  ...                 Dive Spot
# 10                         Birkhadem  ...            Sandwich Place
# 11                          Birtouta  ...        Falafel Restaurant
# 12                         Bologhine  ...              Dessert Shop
# 13                    Bordj El Bahri  ...          Department Store
# 14  Bordj El Kiffan (Bordj El Kifan)  ...              Cupcake Shop
# 15                          Bourouba  ...                    Cruise
# 16                         Bouzaréah  ...          Department Store
# 17                      Béni Messous  ...              Burger Joint
# 18                            Casbah  ...                    Lounge
# 19                           Chéraga  ...               Flower Shop
# 20                      Dar El Beïda  ...             Garden Center
# 21                   Djasr Kasentina  ...                     Diner
# 22                            Douéra  ...                 Dive Spot
# 23                            Draria  ...              Dessert Shop
# 24        Dély Ibrahim (Dely Brahim)  ...        Falafel Restaurant
# 25                         El Achour  ...                      Food
# 26                           El Biar  ...            History Museum
# 27                        El Harrach  ...              Burger Joint
# 28                        El Madania  ...            History Museum
# 29                       El Magharia  ...        Light Rail Station
# 30                          El Marsa  ...          Department Store
# 31                       El Mouradia  ...            History Museum
# 32                           H'raoua  ...        Falafel Restaurant
# 33                          Hammamet  ...        Falafel Restaurant
# 34                       Hussein Dey  ...          Department Store
# 35                             Hydra  ...  Mediterranean Restaurant
# 36                          Khraïcia  ...              Dessert Shop
# 37                             Kouba  ...  Mediterranean Restaurant
# 38                           Mahelma  ...                 Dive Spot
# 39                Mohamed Belouizdad  ...  Mediterranean Restaurant
# 40                        Mohammedia  ...              Burger Joint
# 41                      Oued Koriche  ...                      Park
# 42                         Oued Smar  ...         Recreation Center
# 43                      Ouled Chebel  ...        Falafel Restaurant
# 44                       Ouled Fayet  ...                      Food
# 45                          Rahmania  ...        Falafel Restaurant
# 46                      Raïs Hamidou  ...                 Dive Spot
# 47                           Reghaïa  ...        Falafel Restaurant
# 48                            Rouïba  ...                 Dive Spot
# 49                            Saoula  ...              Dessert Shop
# 50        Sidi M'Hamed (Sidi Mhamed)  ...         French Restaurant
# 51                         Souidania  ...        Falafel Restaurant
# 52                          Staouéli  ...        Italian Restaurant
# 53                 Tessala El Merdja  ...        Falafel Restaurant
# 54                           Zéralda  ...                 Dive Spot
#
# [55 rows x 11 columns]

# %%
#create clustering dataframe that contains categories of venues
Algiers_grouped_clustering = Algiers_grouped.drop('Township', 1)
Algiers_grouped_clustering
# Out:
#     African Restaurant  Airport  ...  Turkish Restaurant  Video Game Store
# 0             0.026316     0.00  ...            0.000000          0.026316
# 1             0.000000     0.00  ...            0.000000          0.000000
# 2             0.000000     0.00  ...            0.000000          0.000000
# 3             0.000000     0.00  ...            0.000000          0.034483
# 4             0.055556     0.00  ...            0.055556          0.000000
# 5             0.000000     0.00  ...            0.000000          0.000000
# 6             0.000000     0.00  ...            0.000000          0.000000
# 7             0.000000     0.00  ...            0.000000          0.000000
# 8             0.023810     0.00  ...            0.023810          0.000000
# 9             0.000000     0.00  ...            0.000000          0.000000
# 10            0.000000     0.00  ...            0.000000          0.000000
# 11            0.000000     0.00  ...            0.000000          0.000000
# 12            0.000000     0.00  ...            0.000000          0.000000
# 13            0.000000     0.00  ...            0.000000          0.000000
# 14            0.100000     0.00  ...            0.000000          0.000000
# 15            0.000000     0.00  ...            0.000000          0.000000
# 16            0.000000     0.00  ...            0.000000          0.000000
# 17            0.000000     0.00  ...            0.047619          0.000000
# 18            0.028571     0.00  ...            0.000000          0.028571
# 19            0.000000     0.00  ...            0.076923          0.000000
# 20            0.076923     0.00  ...            0.000000          0.000000
# 21            0.000000     0.00  ...            0.000000          0.000000
# 22            0.000000     0.00  ...            0.000000          0.000000
# 23            0.000000     0.00  ...            0.000000          0.000000
# 24            0.000000     0.00  ...            0.071429          0.000000
# 25            0.000000     0.00  ...            0.052632          0.000000
# 26            0.023810     0.00  ...            0.023810          0.000000
# 27            0.000000     0.00  ...            0.000000          0.000000
# 28            0.037736     0.00  ...            0.000000          0.000000
# 29            0.000000     0.00  ...            0.000000          0.000000
# 30            0.000000     0.00  ...            0.000000          0.000000
# 31            0.028986     0.00  ...            0.014493          0.000000
# 32            0.000000     0.00  ...            0.000000          0.000000
# 33            0.000000     0.00  ...            0.333333          0.000000
# 34            0.043478     0.00  ...            0.000000          0.000000
# 35            0.035088     0.00  ...            0.017544          0.000000
# 36            0.000000     0.00  ...            0.000000          0.000000
# 37            0.040000     0.00  ...            0.000000          0.000000
# 38            0.000000     0.25  ...            0.000000          0.000000
# 39            0.032258     0.00  ...            0.000000          0.000000
# 40            0.000000     0.00  ...            0.000000          0.000000
# 41            0.031250     0.00  ...            0.000000          0.000000
# 42            0.000000     0.00  ...            0.050000          0.000000
# 43            0.000000     0.00  ...            0.000000          0.000000
# 44            0.000000     0.00  ...            0.090909          0.000000
# 45            0.000000     0.50  ...            0.000000          0.000000
# 46            0.000000     0.00  ...            0.000000          0.000000
# 47            0.000000     0.00  ...            0.000000          0.000000
# 48            0.000000     0.00  ...            0.000000          0.000000
# 49            0.000000     0.00  ...            0.000000          0.000000
# 50            0.028571     0.00  ...            0.014286          0.000000
# 51            0.000000     0.50  ...            0.000000          0.000000
# 52            0.000000     0.00  ...            0.000000          0.000000
# 53            0.000000     0.00  ...            0.000000          0.000000
# 54            0.000000     0.00  ...            0.000000          0.000000
#
# [55 rows x 87 columns]

# %%
# set number of clusters
kclusters =7
# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=1).fit(Algiers_grouped_clustering)
# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 5, 1, 0, 1, 0, 0, 3, 0, 0], dtype=int32)

# %%
# add clustering labels
Townships_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
Algiers_merged = Algiers_city
Algiers_merged = Algiers_merged.join(Townships_venues_sorted.set_index('Township'), on='Township')

# %%
Algiers_merged['Cluster Labels'].value_counts()
# Out:
# 0.0    40
# 1.0     6
# 6.0     3
# 2.0     2
# 5.0     2
# 4.0     1
# 3.0     1
# Name: Cluster Labels, dtype: int64

# %%
Algiers_merged['Cluster Labels']=Algiers_merged['Cluster Labels'].fillna(3).astype(int)

# %%
# create map
City_latitude=36.7538
City_longitude=3.0588
map_clusters = folium.Map(location=[City_latitude,City_longitude], zoom_start=10)
# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Algiers_merged['Latitude'], Algiers_merged['Longitude'], Algiers_merged['Township'], Algiers_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Algiers_merged.loc[Algiers_merged['Cluster Labels'] == 0, Algiers_merged.columns[[0] + list(range(1, Algiers_merged.shape[1]))]]
# Out:
#      Latitude  Longitude  ...       9th Most Common Venue    10th Most Common Venue
# 0   36.776302   3.058486  ...                  Lighthouse                      Park
# 3   36.790665   3.049736  ...        Fast Food Restaurant        Italian Restaurant
# 5   36.694378   2.971822  ...                Cupcake Shop          Department Store
# 6   36.723026   3.113073  ...           Convenience Store                    Cruise
# 8   36.759271   3.019717  ...                  Steakhouse               Coffee Shop
# 9   36.707037   3.040779  ...                Dessert Shop                 Dive Spot
# 10  36.715460   3.049071  ...               Historic Site            Sandwich Place
# 13  36.790795   3.250177  ...                Cupcake Shop          Department Store
# 15  36.717403   3.121664  ...           Convenience Store                    Cruise
# 16  36.777520   2.997065  ...                        Café          Department Store
# 17  36.779616   2.975394  ...              Clothing Store              Burger Joint
# 18  36.784677   3.059586  ...    Mediterranean Restaurant                    Lounge
# 19  36.758945   2.945459  ...                      Office               Flower Shop
# 21  36.669409   2.942103  ...                       Diner                 Dive Spot
# 22  36.689570   2.973539  ...            Department Store              Dessert Shop
# 23  36.751970   2.981650  ...                Burger Joint        Falafel Restaurant
# 24  36.734162   2.990524  ...          Italian Restaurant                      Food
# 25  36.768998   3.029947  ...          Turkish Restaurant            History Museum
# 26  36.721231   3.137410  ...                  Restaurant              Burger Joint
# 27  36.742007   3.066571  ...                      Lounge            History Museum
# 28  36.731335   3.108557  ...                  Restaurant        Light Rail Station
# 29  36.809128   3.254604  ...                Cupcake Shop          Department Store
# 30  36.747496   3.050094  ...          African Restaurant            History Museum
# 31  36.692940   3.071310  ...                Dessert Shop                     Diner
# 33  36.812813   2.973815  ...                   Dive Spot        Falafel Restaurant
# 34  36.730413   3.087835  ...    Mediterranean Restaurant          Department Store
# 35  36.747426   3.040183  ...             Harbor / Marina  Mediterranean Restaurant
# 36  36.677187   2.981770  ...            Department Store              Dessert Shop
# 37  36.733768   3.086179  ...                      Lounge  Mediterranean Restaurant
# 40  36.744241   3.078396  ...               Metro Station  Mediterranean Restaurant
# 41  36.728871   3.146918  ...           Recreation Center              Burger Joint
# 42  36.784924   3.043447  ...                      Lounge                      Park
# 43  36.704420   3.168156  ...                Dessert Shop         Recreation Center
# 45  36.735525   2.950906  ...  Construction & Landscaping                      Food
# 47  36.817336   3.011517  ...                       Diner                 Dive Spot
# 48  36.738781   3.342118  ...                   Dive Spot        Falafel Restaurant
# 49  36.742651   3.310621  ...                Dessert Shop                 Dive Spot
# 50  36.702446   3.026597  ...            Department Store              Dessert Shop
# 51  36.764424   3.049632  ...              History Museum         French Restaurant
# 54  36.753340   2.888176  ...                 Music Venue        Italian Restaurant
#
# [40 rows x 14 columns]

# %%
Algiers_merged.loc[Algiers_merged['Cluster Labels'] == 1, Algiers_merged.columns[[0] + list(range(2, Algiers_merged.shape[1]))]]
# Out:
#      Latitude  ... 10th Most Common Venue
# 2   36.792881  ...     Falafel Restaurant
# 4   36.721997  ...     Italian Restaurant
# 14  36.747273  ...           Cupcake Shop
# 20  36.741000  ...          Garden Center
# 32  36.772746  ...     Falafel Restaurant
# 56  36.699282  ...              Dive Spot
#
# [6 rows x 13 columns]

# %%
Algiers_merged.loc[Algiers_merged['Cluster Labels'] == 2, Algiers_merged.columns[[0] + list(range(2, Algiers_merged.shape[1]))]]
# Out:
#      Latitude           Township  ...  9th Most Common Venue 10th Most Common Venue
# 11  36.623933           Birtouta  ...              Dive Spot     Falafel Restaurant
# 55  36.630719  Tessala El Merdja  ...              Dive Spot     Falafel Restaurant
#
# [2 rows x 13 columns]

# %%
Algiers_merged.loc[Algiers_merged['Cluster Labels'] == 3, Algiers_merged.columns[[0] + list(range(2, Algiers_merged.shape[1]))]]
# Out:
#      Latitude        Township  ...  9th Most Common Venue 10th Most Common Venue
# 7   36.642065          Baraki  ...              Dive Spot     Falafel Restaurant
# 38  36.656714  Les Eucalyptus  ...                    NaN                    NaN
# 52  36.606254     Sidi Moussa  ...                    NaN                    NaN
#
# [3 rows x 13 columns]

# %%
Algiers_merged.loc[Algiers_merged['Cluster Labels'] == 4, Algiers_merged.columns[[0] + list(range(2, Algiers_merged.shape[1]))]]
# Out:
#      Latitude      Township  ...  9th Most Common Venue 10th Most Common Venue
# 44  36.608387  Ouled Chebel  ...              Dive Spot     Falafel Restaurant
#
# [1 rows x 13 columns]

# %%
Algiers_merged.loc[Algiers_merged['Cluster Labels'] == 5, Algiers_merged.columns[[0] + list(range(2, Algiers_merged.shape[1]))]]
# Out:
#      Latitude    Township  ...  9th Most Common Venue 10th Most Common Venue
# 1   36.803804  Aïn Bénian  ...           Dessert Shop                  Diner
# 12  36.804678   Bologhine  ...       Department Store           Dessert Shop
#
# [2 rows x 13 columns]

# %%
Algiers_merged.loc[Algiers_merged['Cluster Labels'] == 6, Algiers_merged.columns[[0] + list(range(2, Algiers_merged.shape[1]))]]
# Out:
#      Latitude   Township  ...  9th Most Common Venue 10th Most Common Venue
# 39  36.682363    Mahelma  ...                  Diner              Dive Spot
# 46  36.680763   Rahmania  ...              Dive Spot     Falafel Restaurant
# 53  36.707975  Souidania  ...              Dive Spot     Falafel Restaurant
#
# [3 rows x 13 columns]

# %%
Algiers_merged.loc[Algiers_merged['Cluster Labels'] == 7, Algiers_merged.columns[[0] + list(range(2, Algiers_merged.shape[1]))]]
# Out:
# Empty DataFrame
# Columns: [Latitude, Township, Cluster Labels, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %%
Algiers_merged.loc[Algiers_merged['Cluster Labels'] == 8, Algiers_merged.columns[[0] + list(range(2, Algiers_merged.shape[1]))]]
# Out:
# Empty DataFrame
# Columns: [Latitude, Township, Cluster Labels, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %%
Algiers_merged.loc[Algiers_merged['Cluster Labels'] == 9, Algiers_merged.columns[[0] + list(range(3, Algiers_merged.shape[1]))]]
# Out:
# Empty DataFrame
# Columns: [Latitude, Cluster Labels, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []
